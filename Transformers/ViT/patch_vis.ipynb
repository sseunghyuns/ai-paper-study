# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_w = 512
img_h = 384
patch_size = 32

# %%
sample.shape
# Out:
# torch.Size([192, 3, 32, 32])

# %%
image = Image.open('sample/elephant.jpg').resize((img_w, img_h)) # W, H
image = np.array(image)
image.shape # H, W, C
t_image = torch.tensor(image).unsqueeze(0)
sample = t_image.unfold(1, patch_size, patch_size).unfold(2, patch_size, patch_size).reshape(-1, 3, patch_size, patch_size)
img = torchvision.utils.make_grid(sample, nrow=int(img_w/patch_size))

fig , axes = plt.subplots(1,2)
fig.set_size_inches(15,8)
axes[0].imshow(image)
axes[1].imshow(img.permute(1,2,0).numpy())
